# %%
X = df.select_dtypes(include='number')

kmeans = KMeans(n_clusters=3)
clusters = kmeans.fit_predict(X)

df['cluster'] = clusters

sns.scatterplot(x=X.iloc[:,0], y=X.iloc[:,1], hue=clusters, palette="tab10")
plt.show()
